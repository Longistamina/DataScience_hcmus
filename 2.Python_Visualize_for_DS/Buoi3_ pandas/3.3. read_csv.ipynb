# %%
import numpy as np
import pandas as pd

# %%
weather = pd.read_csv('daily_weather(11).csv', index_col=0) #Chọn cột đầu tiên làm cột index
weather.head()
# Out:
#         air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# number
# 0             918.060000     74.822000              271.100000
# 1             917.347688     71.403843              101.935179
# 2             923.040000     60.638000               51.000000
# 3             920.502751     70.138895              198.832133
# 4             921.160000     44.294000              277.800000
#
#         avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# number
# 0                 2.080354              295.400000            2.863283
# 1                 2.443009              140.471549            3.533324
# 2                17.067852               63.700000           22.100967
# 3                 4.337363              211.203341            5.190045
# 4                 1.856660              136.500000            2.863283
#
#         rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# number
# ...

# %%
drinks = pd.read_csv('drinks.csv',index_col=0)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.shape #Kinh nghiệm là sau khi đọc xong thì nên coi shape
# Out:
# (193, 6)

# %%
#Kiem tra xem co gia tri null hay khong ? np.nan hoac .isnull()
drinks.isnull().sum() #Thêm .sum() để nó thống kê tổng số giá trị null ở các cột
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks[drinks.continent.isnull()] #Hiện những quốc gia mà có cột continent là null/nan
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...
