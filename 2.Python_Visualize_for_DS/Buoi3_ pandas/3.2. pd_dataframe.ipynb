# %%
import numpy as np
import pandas as pd

# %%
lst1=[1,2,3,4,5]
df1 = pd.DataFrame(lst1) #Tạo df một chiều từ list

# %%
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
lst2 = [['Bibi',7],['Xuxu',15],['Nana',10]]
df2 = pd.DataFrame(lst2, columns=['Name','Age']) #Tạo df 2 chiều, columns =... để đặt tên cột

# %%
df2
# Out:
#    Name  Age
# 0  Bibi    7
# 1  Xuxu   15
# 2  Nana   10

# %%
dict_data = {'name':['Jack','Bill','Berserk'], 'age':[15,29,22]}
df3 = pd.DataFrame(dict_data) #Tạo df từ dictionary

# %%
df3
# Out:
#       name  age
# 0     Jack   15
# 1     Bill   29
# 2  Berserk   22

# %%
df3['name'] #Tham chiếu bằng tên cột
# Out:
# 0       Jack
# 1       Bill
# 2    Berserk
# Name: name, dtype: object

# %%
dict_data = {'name':['Jack','Bill','Berserk'], 'age':[15,29,22]}
df3 = pd.DataFrame(dict_data, index = ['std1','std2','std3'])

# %%
df3
# Out:
#          name  age
# std1     Jack   15
# std2     Bill   29
# std3  Berserk   22

# %%
#Tham chieu theo dong`
df3.loc['std3'] #Tham chiếu đến location (dòng) có tên std3
# Out:
# name    Berserk
# age          22
# Name: std3, dtype: object

# %%
df3.iloc[2] #Tham chiếu đến location có idex = 2
# Out:
# name    Berserk
# age          22
# Name: std3, dtype: object

# %%
df3.loc['std2','age'] = 24 #Thay đổi giá trị có index lable 'std2', ở cột 'age' thành 24

# %%
dict_data = {'name':['Jack','Bill','Berserk'], 'age':[15,29,22]}
df4 = pd.DataFrame(dict_data)
df4
# Out:
#       name  age
# 0     Jack   15
# 1     Bill   29
# 2  Berserk   22

# %%
df4.loc[1,'age'] = 24 #Sửa giá trị ở dòng có index=1 ở cột age thành 24

# %%
df4
# Out:
#       name  age
# 0     Jack   15
# 1     Bill   24
# 2  Berserk   22

# %%
#Đọc file csv
wines = pd.read_csv('/home/long/Documents/Data Science/2. Python for DS/file of Bảng tin/winequality-red.csv', sep=';') 
# sep = ; Để nó hiểu ; là ngăn cắt giữa các cột

# %%
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wines.columns #Xem tất cả tên cột
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wines.info() #Xem thông tin đầy đủ hơn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wines.head() #Xem 5 dòng đầu
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wines.tail() #Xem 5 dòng cuối
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
wines.mean() #Tính trung bình cho tất cả cột
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64

# %%
wines[['fixed acidity','residual sugar','quality']] #Tham chiếu nhiều cột, cho tên các cột vào list
# Out:
#       fixed acidity  residual sugar  quality
# 0               7.4             1.9        5
# 1               7.8             2.6        5
# 2               7.8             2.3        5
# 3              11.2             1.9        6
# 4               7.4             1.9        5
# ...             ...             ...      ...
# 1594            6.2             2.0        5
# 1595            5.9             2.2        6
# 1596            6.3             2.3        6
# 1597            5.9             2.0        5
# 1598            6.0             3.6        6
#
# [1599 rows x 3 columns]

# %%
wines[['fixed acidity','residual sugar','quality']].mean() #Tính mean cho các cột được truy xuất
# Out:
# fixed acidity     8.319637
# residual sugar    2.538806
# quality           5.636023
# dtype: float64

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wines.describe().T #Dùng .T để  chuyển vị lại ma trận kết quả, cho dễ nhìn hơn
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
wines['quality'].value_counts() #Đếm tần số  lần xuất hiện của tất cả giá trị trong cột quality
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
wines[wines['quality']==5] #Truy xuất những dòng có quality = 5
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1589            6.6             0.725         0.20             7.8      0.073
# 1594            6.2             0.600         0.08             2.0      0.090
# 1597            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#Sap xep TANG dan theo cot 'residual sugar'
wines.sort_values(by='residual sugar')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1018            8.0             0.180         0.37             0.9      0.049
# 1017            8.0             0.180         0.37             0.9      0.049
# 1374            6.8             0.815         0.00             1.2      0.267
# 1321            5.0             0.740         0.00             1.2      0.041
# 469             8.7             0.820         0.02             1.2      0.070
# ...             ...               ...          ...             ...        ...
# 1476            9.9             0.500         0.50            13.8      0.205
# 1574            5.6             0.310         0.78            13.9      0.074
# 1435           10.2             0.540         0.37            15.4      0.214
# 1434           10.2             0.540         0.37            15.4      0.214
# 480            10.6             0.280         0.39            15.5      0.069
#
# ...

# %%
#Sap xep GIAM dan theo cot 'residual sugar'
wines.sort_values(by='residual sugar', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 480            10.6             0.280         0.39            15.5      0.069
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 1574            5.6             0.310         0.78            13.9      0.074
# 1474            9.9             0.500         0.50            13.8      0.205
# ...             ...               ...          ...             ...        ...
# 1374            6.8             0.815         0.00             1.2      0.267
# 1321            5.0             0.740         0.00             1.2      0.041
# 469             8.7             0.820         0.02             1.2      0.070
# 1017            8.0             0.180         0.37             0.9      0.049
# 1018            8.0             0.180         0.37             0.9      0.049
#
# ...

# %%
cond = (wines['quality']>=5) & (wines['alcohol']>=10) #Tạo biểu thức chứa nhiều điều kiện
wines[cond]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3             0.650         0.00             1.2      0.065
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 16              8.5             0.280         0.56             1.8      0.092
# 30              6.7             0.675         0.07             2.4      0.089
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
