# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = open('/home/long/Documents/Data Science/2. Python for DS/file of Bảng tin/heights_1.txt')
data = f.read()
f.close
lst_hei = eval(data)
df_h=pd.DataFrame({'Heights_inch':lst_hei})
df_h['Heights_m']=df_h['Heights_inch']*0.0254 #Thêm cột Heights_m vào, giá trị h_m bằng h_inch*0.0254
df_h.head()
# Out:
#    Heights_inch  Heights_m
# 0            74     1.8796
# 1            74     1.8796
# 2            72     1.8288
# 3            72     1.8288
# 4            73     1.8542

# %%
# nếu chỉ df.plot() thì mặc định nó sẽ vẽ biểu đồ đường (line)
df_h['Heights_m'][:20].plot()
# Out:
# <Axes: >

# %%
dfHS = pd.DataFrame({'Ten':['Tung','Thanh','Ngoc','Lan','Bao'],
                    'Toan':[5.6,7.8,8.5,4.3,7.4],
                    'Ly':[7.8,8.2,6.7,9.5,6.5],
                    'Hoa':[2.0,5.7,8.9,5.7,6.7]})
dfHS.set_index('Ten',inplace=True)
dfHS
# Out:
#        Toan   Ly  Hoa
# Ten
# Tung    5.6  7.8  2.0
# Thanh   7.8  8.2  5.7
# Ngoc    8.5  6.7  8.9
# Lan     4.3  9.5  5.7
# Bao     7.4  6.5  6.7

# %%
dfHS.plot()
# Out:
# <Axes: xlabel='Ten'>
