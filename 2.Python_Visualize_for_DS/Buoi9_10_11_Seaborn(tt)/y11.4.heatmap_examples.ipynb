# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('vd_seaborn/daily_show_guests_cleaned.csv') 
# we will start by looking at guests of the Daily Show from 1999 - 2015 
# and see how the occupations of the guests have changed over time.

# %%
df.shape
# Out:
# (2693, 5)

# %%
df.head()
# Out:
#    YEAR GoogleKnowlege_Occupation     Show   Group    Raw_Guest_List
# 0  1999                     actor  1/11/99  Acting    Michael J. Fox
# 1  1999                  Comedian  1/12/99  Comedy   Sandra Bernhard
# 2  1999        television actress  1/13/99  Acting     Tracey Ullman
# 3  1999              film actress  1/14/99  Acting  Gillian Anderson
# 4  1999                     actor  1/18/99  Acting  David Alan Grier

# %%
df_ = pd.crosstab(df['Group'], df['YEAR'])

# %%
df_
# Out:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_, cbar=False, cmap='YlGnBu', linewidths=0.3)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
# vẽ heatmap cho các chuyến bay deplay trong năm
# Path of the file to read
flight_filepath = "vd_seaborn/flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %%
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,8))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True, linewidths=0.5) #annot = True để  nó hiện ra số  dữ liệu giữa ô heatmap

# Add label for horizontal axis
plt.xlabel("Airline");

# %%
#----------------Tính hệ số tương quan, rồi lấy kết quả đó xây dựng heatmap--------------------------#

iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.corr() # tinh he so tuong quan correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(iris.corr())
plt.yticks(rotation=0)
plt.xticks(rotation=45)
plt.show()
