# %%
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 10 quán café xung quanh 137E Nguyễn Chí Thanh với bán kính 1km
df = pd.read_csv('data/coffeePlace.csv')

# %%
df
# Out:
#    Unnamed: 0                                    name  checkins  \
# 0           0                   Passio Coffee Vietnam        41
# 1           1  Coffee Phố Hương Thành Phố Hồ Chí Minh       299
# 2           2                             Sama coffee       293
# 3           3     Coffee Thềm Xưa Nguyễn Cảnh Chân Q1        69
# 4           4                          Coffee Bida 68        10
# 5           5                         Check In Coffee         5
# 6           6                                Bida 336       416
# 7           7               Oval Coffee 68 Đào Duy Từ      1095
#
#                                             location                id  \
# 0  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   105142024251290
# 1  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   100549471341440
# 2  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   209070719490589
# 3  {'city': 'Ho Chi Minh City', 'country': 'Vietn...  1623765911195368
# 4  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   114125302473404
# 5  {'city': 'Quận 12', 'country': 'Vietnam', 'lat...   103366044776121
# 6  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   582592282100399
# 7  {'city': 'Ho Chi Minh City', 'country': 'Vietn...   466298203476956
#
#          lat         lng
# 0  10.759100  106.664600
# 1  10.754696  106.666548
# 2  10.758920  106.664260
# 3  10.754438  106.671120
# 4  10.760650  106.665290
# 5  10.758265  106.664487
# 6  10.759540  106.666700
# 7  10.760286  106.666327

# %%
# vi tri 137E Nguyen Chi Thanh
cen_latitude = 10.7590685
cen_longitude = 106.6644998
hcm_map = folium.Map(location=[cen_latitude, cen_longitude], zoom_start=15)

#Vi tri cac quan cafe
for lat, lng, label in zip(df.lat, df.lng, df.name):
    folium.Marker(location=[lat, lng], tooltip=label).add_to(hcm_map)
hcm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b03ecbd7020e17faac82cf13aa93db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b03ecbd7020e17faac82cf13aa93db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b03ecbd7020e17faac82cf13aa93db = L.map(
#                 &quot;map_51b03ecbd7020e17faac82cf13aa93db&quot;,
#                 {
#                     center: [10.7590685, 106.6644998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f91cdc4967c7bd2f459727d87470ff4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f91cdc4967c7bd2f459727d87470ff4f.addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             var marker_91be9d7f07ef231371875acc08c38739 = L.marker(
#                 [10.7591, 106.6645999],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_91be9d7f07ef231371875acc08c38739.bindTooltip(
#                 `&lt;div&gt;
#                      Passio Coffee Vietnam
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_05e0a4cd22f3daa80a5e5f9c4be372e5 = L.marker(
#                 [10.754696, 106.6665481],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_05e0a4cd22f3daa80a5e5f9c4be372e5.bindTooltip(
#                 `&lt;div&gt;
#                      Coffee Phố Hương Thành Phố Hồ Chí Minh
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9efe55207c3990164989022f896483be = L.marker(
#                 [10.75892, 106.66426],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_9efe55207c3990164989022f896483be.bindTooltip(
#                 `&lt;div&gt;
#                      Sama coffee
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9a5c8572519e05ed5c9c9bd57b5406ea = L.marker(
#                 [10.754438400269, 106.67111968994],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_9a5c8572519e05ed5c9c9bd57b5406ea.bindTooltip(
#                 `&lt;div&gt;
#                      Coffee Thềm Xưa Nguyễn Cảnh Chân Q1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c5e50ca09e9ee118c82648733b82c685 = L.marker(
#                 [10.76065, 106.66529],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_c5e50ca09e9ee118c82648733b82c685.bindTooltip(
#                 `&lt;div&gt;
#                      Coffee Bida 68
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d0e7eefee3c3de5f051d36967f6b4c0c = L.marker(
#                 [10.75826540458, 106.66448682239],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_d0e7eefee3c3de5f051d36967f6b4c0c.bindTooltip(
#                 `&lt;div&gt;
#                      Check In Coffee
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d3470907fef2d1776ed188b2e32ffaf = L.marker(
#                 [10.75954, 106.6667],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_4d3470907fef2d1776ed188b2e32ffaf.bindTooltip(
#                 `&lt;div&gt;
#                      Bida 336
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdd52e7287783f7ed9cd9511ca7d3543 = L.marker(
#                 [10.760285717121, 106.66632697288],
#                 {}
#             ).addTo(map_51b03ecbd7020e17faac82cf13aa93db);
#
#
#             marker_bdd52e7287783f7ed9cd9511ca7d3543.bindTooltip(
#                 `&lt;div&gt;
#                      Oval Coffee 68 Đào Duy Từ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# vi tri 137E Nguyen Chi Thanh
cen_latitude = 10.7590685
cen_longitude = 106.6644998
hcm_map = folium.Map(location=[cen_latitude, cen_longitude], zoom_start=15)
# tao cac marker (la cac popup)
for lat, lng, label in zip(df.lat, df.lng, df.name):
    text = '<b>'+label+'</b>'
    folium.Marker(location=[lat, lng], tooltip=text).add_to(hcm_map)
# ve ban do
hcm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc9cc1ada8457a3f71b1a4e9fd0e224 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc9cc1ada8457a3f71b1a4e9fd0e224&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc9cc1ada8457a3f71b1a4e9fd0e224 = L.map(
#                 &quot;map_3bc9cc1ada8457a3f71b1a4e9fd0e224&quot;,
#                 {
#                     center: [10.7590685, 106.6644998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d20abef72306585619e87438b7baf1b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d20abef72306585619e87438b7baf1b1.addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             var marker_e7d7d4a8157e8c79198a8ee5ef721ff9 = L.marker(
#                 [10.7591, 106.6645999],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_e7d7d4a8157e8c79198a8ee5ef721ff9.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Passio Coffee Vietnam&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_092deec7813238cb3bc7450a143f01ed = L.marker(
#                 [10.754696, 106.6665481],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_092deec7813238cb3bc7450a143f01ed.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Coffee Phố Hương Thành Phố Hồ Chí Minh&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fa88dc7590a1f002180fde5733c960fb = L.marker(
#                 [10.75892, 106.66426],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_fa88dc7590a1f002180fde5733c960fb.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Sama coffee&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40bbda79149fda1cb6ff8db178aed3d9 = L.marker(
#                 [10.754438400269, 106.67111968994],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_40bbda79149fda1cb6ff8db178aed3d9.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Coffee Thềm Xưa Nguyễn Cảnh Chân Q1&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be6e7ad531528c8561eaec3028e3d056 = L.marker(
#                 [10.76065, 106.66529],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_be6e7ad531528c8561eaec3028e3d056.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Coffee Bida 68&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d61fb83d26a6dada6e5007e7d5723d39 = L.marker(
#                 [10.75826540458, 106.66448682239],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_d61fb83d26a6dada6e5007e7d5723d39.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Check In Coffee&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3189bf54f6ee6c4c0a02263e2a7d7ee6 = L.marker(
#                 [10.75954, 106.6667],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_3189bf54f6ee6c4c0a02263e2a7d7ee6.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Bida 336&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a21d8eb2621da2f991fad46da121d64e = L.marker(
#                 [10.760285717121, 106.66632697288],
#                 {}
#             ).addTo(map_3bc9cc1ada8457a3f71b1a4e9fd0e224);
#
#
#             marker_a21d8eb2621da2f991fad46da121d64e.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Oval Coffee 68 Đào Duy Từ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
