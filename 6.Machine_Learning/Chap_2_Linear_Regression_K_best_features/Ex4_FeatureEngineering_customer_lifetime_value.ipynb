# %% [markdown]
# ### "Customer Lifetime Value (CLTV) - Giá trị trọn đời của khách hàng là giá trị tiền tệ đại diện cho số tiền doanh thu hoặc lợi nhuận mà khách hàng sẽ mang lại cho công ty trong suốt thời gian của mối quan hệ". CLTV cho thấy ý nghĩa của việc có được khách hàng dài hạn so với khách hàng ngắn hạn. Giá trị trọn đời của khách hàng (CLV) có thể giúp trả lời các câu hỏi quan trọng nhất về bán hàng cho mọi công ty:
# + Làm thế nào để xác định khách hàng có lợi nhuận cao nhất?
# + Làm thế nào một công ty có thể cung cấp sản phẩm tốt nhất và kiếm được nhiều tiền nhất?
# + Làm thế nào để phân khúc khách hàng có lợi nhuận?
# + Cần bao nhiêu ngân sách để có được khách hàng?
#
# ### Trong marketing, CLV là một trong những số liệu chính cần có và theo dõi.
# + Nhìn chung, để có được khách hàng mới tốn kém hơn là giữ khách hàng hiện tại, vì vậy biết giá trị trọn đời và chi phí liên quan đến việc có được khách hàng mới là điều cần thiết để xây dựng chiến lược tiếp thị với positive ROI tích cực.
# ### Ví dụ:
# + Nếu CLV trung bình của khách hàng là 100 usd và và chỉ tốn 10 usd để có được một khách hàng mới, thì doanh nghiệp sẽ tạo thêm doanh thu khi có được khách hàng mới.
# + Tuy nhiên, nếu chi phí 150 usd để có được một khách hàng mới và CLV trung bình của khách hàng vẫn là 100 usd, thì sẽ mất tiền cho mỗi lần có một khách hàng mới. Như vậy, nếu chi tiêu tiếp thị cho việc có thêm một khách hàng mới vượt quá CLV, ta sẽ mất tiền cho mỗi lần có thêm một khách hàng => Trường hợp này, tốt hơn là nên làm việc với các khách hàng hiện tại.
#
# ### Có nhiều cách để tính CLV
# + Một cách là tìm số tiền mua trung bình của khách hàng (customer's average purchase amount), tần suất mua (purchase frequency) và tuổi thọ (lifetime span) và thực hiện một phép tính đơn giản để có được CLV.
# ### Ví dụ:
# + Số tiền mua trung bình của khách hàng là 100 usd, trung bình họ thực hiện mua hàng năm lần mỗi tháng => giá trị trung bình của khách hàng này mỗi tháng là 500 usd (= customer's average purchase amount * purchase frequency). Bây giờ, chúng ta cần biết tuổi thọ của khách hàng này (custumer's lifetime span).
# + Một cách để ước tính tuổi thọ của khách hàng (customer's lifetime spa) là xem tỷ lệ bỏ đi trung bình hàng tháng (average monthly churn rate), là tỷ lệ phần trăm khách hàng bỏ đi hay chấm dứt mối quan hệ với doanh nghiệp. Có thể ước tính tuổi thọ của khách hàng bằng cách chia cho tỷ lệ bỏ đi (churn rate).
# + Giả sử, với tỷ lệ bỏ đi là 5%, tuổi thọ ước tính của khách hàng là 20 năm. Nếu giá trị trung bình của khách hàng mỗi tháng là 500 usd, thì CLV của khách hàng này là 120.000 uds (= 500usd * 12 tháng * 20 năm)
#
# Vì chúng ta thường không biết tuổi thọ của khách hàng (custumer's lifetime span), chúng ta sẽ cố gắng ước tính CLV trong một khoảng thời gian nhất định. Điều này có thể được thực hiện bằng cách ước tính CLV 12 tháng, 24 tháng hoặc cũng có thể là CLV 3 tháng của khách hàng. Ngoài phương pháp đã nêu ở ví dụ trên, CLV cũng có thể được ước tính thông qua việc xây dựng các mô hình dự đoán. Sử dụng thuật toán Machine Learning và dữ liệu lịch sử mua hàng của khách hàng, chúng ta có thể xây dựng các mô hình Machine Learning dự đoán CLV của khách hàng trong một khoảng thời gian nhất định.

# %% [markdown]
# ## Trong bài tập này, cho dữ liệu OnlineRetail.xlsx download tại
# + http://archive.ics.uci.edu/ml/datasets/online+retail
# + (http://archive.ics.uci.edu/ml/datasets/online+retail) chứa dữ liệu lịch sử khách hàng, hãy xây dựng regression model dự đoán CLV 3 tháng tiếp theo của khách hàng.
#
# ## Yêu cầu:
# + Đoc dữ liệu. Tìm hiểu sơ bộ về dữ liệu.
# + Tiền xử lý dữ liệu
# + Phân tích dữ liệu
# + Xây dựng model dự đoán
# + Đánh giá model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# ## <span style='color:yellow'> Data reading

# %%
onl_retail = pd.read_excel('Data/Online_Retail.xlsx')
onl_retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
onl_retail.shape
# Out:
# (541909, 8)

# %%
onl_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ## <span style='color:yellow'> Data preprocessing

# %% [markdown]
# ## Dropping NaN records
# + Cần xóa bỏ những hồ sơ không có CustomerID.
# + Vì chúng ta sẽ xây dựng một mô hình Machine Learning để dự đoán giá trị khách hàng 3 tháng nên cần nhóm dữ liệu theo cột
# CustomerID.
# + Không có CustomerID, chúng ta không thể xây dựng mô hình.

# %%
onl_retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df_cleaned = onl_retail[onl_retail['Quantity'] > 0] #Remove canceled orders
df_cleaned = df_cleaned[pd.notnull(df_cleaned['CustomerID'])] #Remove NaN CustomerID
df_cleaned
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ## Handling incomplete data
# + Bộ dữ liệu chứa các giao dịch trong khoảng thời gian từ ngày 01/12/2010 => 09/12/2011.
# + Trong đó, tháng 12/2011 chưa đủ dữ liệu.
# + Để xây dựng mô hình đúng cho dự đoán giá trkhách hàng 3 tháng, thì cần bỏ qua các giao dịch trong tháng cuối cùng.

# %%
print(f'Date range of data: {df_cleaned['InvoiceDate'].min()} ~ {df_cleaned['InvoiceDate'].max()}\n')
print(f'Number of sales after 12/2011: {df_cleaned[df_cleaned['InvoiceDate'] >= '2011-12-01'].shape[0]}\n')
print(f'Number of sales before 12/2011: {df_cleaned[df_cleaned['InvoiceDate'] < '2011-12-01'].shape[0]}')
# Out:
# Date range of data: 2010-12-01 08:26:00 ~ 2011-12-09 12:50:00
#
# Number of sales after 12/2011: 17304
#
# Number of sales before 12/2011: 380620

# %% [markdown]
# ## Total Sales value
# Tạo cột 'Sales' (total purchase amount for each transaction) = 'Quantity' * 'UnitPrice'

# %%
df_cleaned['Sales'] = df_cleaned.loc[:,'Quantity']*df_cleaned.loc[:,'UnitPrice']
df_cleaned
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Sales
# ...

# %% [markdown]
# ## Per Order Data
# Nhóm dữ liệu theo CustomerID và InvoiceNo

# %%
group_df = df_cleaned.groupby(['CustomerID', 'InvoiceNo']).agg({'Sales':'sum', 'InvoiceDate':'max'})
group_df
# Out:
#                          Sales         InvoiceDate
# CustomerID InvoiceNo
# 12346.0    541431     77183.60 2011-01-18 10:01:00
# 12347.0    537626       711.79 2010-12-07 14:57:00
#            542237       475.39 2011-01-26 14:30:00
#            549222       636.25 2011-04-07 10:43:00
#            556201       382.52 2011-06-09 13:01:00
# ...                        ...                 ...
# 18283.0    579673       223.61 2011-11-30 12:59:00
#            580872       208.00 2011-12-06 12:02:00
# 18287.0    554065       765.28 2011-05-22 10:39:00
#            570715      1001.32 2011-10-12 10:23:00
#            573167        70.68 2011-10-28 09:29:00
#
# [18536 rows x 2 columns]

# %% [markdown]
# ## <span style='color:yellow'>Data Analysis
# Để tính toán CLV, cần biết:
# + purchase_duration (thời gian mua hàng) = day_max - day_min
# + count (số lần mua hàng) của khách hàng
# + purchase_frequency (tần suất mua hàng)  = purchas_duration / count
# + avg (tiền mua hàng trung bình)

# %%
def groupby_mean(x):
    return x.mean()

def groupby_count(x):
    return x.count()

def purchase_duration(x):
    return (x.max() - x.min()).days

def avg_purchase_freq(x):
    return (x.max() - x.min()).days/x.count()

groupby_mean.__name__ = 'avg'
groupby_count.__name__ = 'count'
purchase_duration.__name__ = 'purchase_duration'
avg_purchase_freq.__name__ = 'avg_purchase_freq'

# %%
summary_df = group_df.reset_index().groupby('CustomerID').agg({
    'Sales':['min', 'max', 'sum', groupby_mean, groupby_count],
    'InvoiceDate':['min', 'max', purchase_duration, avg_purchase_freq]
})

summary_df
# Out:
#                Sales                                          \
#                  min       max       sum           avg count
# CustomerID
# 12346.0     77183.60  77183.60  77183.60  77183.600000     1
# 12347.0       224.82   1294.32   4310.00    615.714286     7
# 12348.0       227.44    892.80   1797.24    449.310000     4
# 12349.0      1757.55   1757.55   1757.55   1757.550000     1
# 12350.0       334.40    334.40    334.40    334.400000     1
# ...              ...       ...       ...           ...   ...
# 18280.0       180.60    180.60    180.60    180.600000     1
# 18281.0        80.82     80.82     80.82     80.820000     1
# 18282.0        77.84    100.21    178.05     89.025000     2
# 18283.0         1.95    313.65   2094.88    130.930000    16
# 18287.0        70.68   1001.32   1837.28    612.426667     3
#
#                    InvoiceDate                                        \
#                            min                 max purchase_duration
# CustomerID
# ...

# %%
summary_df.columns
# Out:
# MultiIndex([(      'Sales',               'min'),
#             (      'Sales',               'max'),
#             (      'Sales',               'sum'),
#             (      'Sales',               'avg'),
#             (      'Sales',             'count'),
#             ('InvoiceDate',               'min'),
#             ('InvoiceDate',               'max'),
#             ('InvoiceDate', 'purchase_duration'),
#             ('InvoiceDate', 'avg_purchase_freq')],
#            )

# %%
summary_df.columns = ['_'.join(col) for col in summary_df.columns]
#(      'Sales',               'min') => join Sales_min
summary_df
# Out:
#             Sales_min  Sales_max  Sales_sum     Sales_avg  Sales_count  \
# CustomerID
# 12346.0      77183.60   77183.60   77183.60  77183.600000            1
# 12347.0        224.82    1294.32    4310.00    615.714286            7
# 12348.0        227.44     892.80    1797.24    449.310000            4
# 12349.0       1757.55    1757.55    1757.55   1757.550000            1
# 12350.0        334.40     334.40     334.40    334.400000            1
# ...               ...        ...        ...           ...          ...
# 18280.0        180.60     180.60     180.60    180.600000            1
# 18281.0         80.82      80.82      80.82     80.820000            1
# 18282.0         77.84     100.21     178.05     89.025000            2
# 18283.0          1.95     313.65    2094.88    130.930000           16
# 18287.0         70.68    1001.32    1837.28    612.426667            3
#
#                InvoiceDate_min     InvoiceDate_max  \
# CustomerID
# ...

# %%
summary_df = summary_df[summary_df['InvoiceDate_purchase_duration'] > 0]
#remove customer only buy one time

summary_df
# Out:
#             Sales_min  Sales_max  Sales_sum   Sales_avg  Sales_count  \
# CustomerID
# 12347.0        224.82    1294.32    4310.00  615.714286            7
# 12348.0        227.44     892.80    1797.24  449.310000            4
# 12352.0        120.33     840.30    2506.04  313.255000            8
# 12356.0         58.35    2271.62    2811.43  937.143333            3
# 12358.0        484.86     683.20    1168.06  584.030000            2
# ...               ...        ...        ...         ...          ...
# 18272.0        340.72     753.66    3078.58  513.096667            6
# 18273.0         51.00     102.00     204.00   68.000000            3
# 18282.0         77.84     100.21     178.05   89.025000            2
# 18283.0          1.95     313.65    2094.88  130.930000           16
# 18287.0         70.68    1001.32    1837.28  612.426667            3
#
#                InvoiceDate_min     InvoiceDate_max  \
# CustomerID
# 12347.0    2010-12-07 14:57:00 2011-12-07 15:52:00
# ...

# %% [markdown]
# ## Visualization

# %%
sbn.set_theme(style='darkgrid')
summary_df.groupby('Sales_count').count()['Sales_avg'].plot(
    kind='bar',
    color='green',
    figsize=(12,7)
)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# + Comment: most of the customers order only 9 times or below

# %%
sbn.histplot(summary_df['InvoiceDate_avg_purchase_freq'])
plt.xlabel('Average number of days between sale')
plt.show()

# %% [markdown]
# + Comment: averagely, most of customers will have new order after 50 days

# %% [markdown]
# ## <span style='color:yellow'>Predicting 3-Month CLV
# + Trong phần này, chúng ta sẽ xây dựng một mô hình dự đoán giá trị khách hàng 3 tháng.
# + Trước tiên, cần cắt dữ liệu thành các khối trong 3 tháng và lấy dữ liệu của 3 tháng cuối làm target cho các dự đoán và phần còn lại làm feature.
#
# ##  <span style='color:yellow'> Use Grouper

# %%
df_3M = group_df.reset_index().groupby(['CustomerID', pd.Grouper(key='InvoiceDate', freq='3M')]).agg({'Sales':['sum', groupby_mean, groupby_count]})

df_3M.columns = ['_'.join(col) for col in df_3M.columns]
df_3M = df_3M.reset_index()
df_3M
# Out:
# /tmp/ipykernel_8742/2680328672.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_3M = group_df.reset_index().groupby(['CustomerID', pd.Grouper(key='InvoiceDate', freq='3M')]).agg({'Sales':['sum', groupby_mean, groupby_count]})
#       CustomerID InvoiceDate  Sales_sum     Sales_avg  Sales_count
# 0        12346.0  2011-03-31   77183.60  77183.600000            1
# 1        12347.0  2010-12-31     711.79    711.790000            1
# 2        12347.0  2011-03-31     475.39    475.390000            1
# 3        12347.0  2011-06-30    1018.77    509.385000            2
# 4        12347.0  2011-09-30     584.91    584.910000            1
# ...          ...         ...        ...           ...          ...
# 9369     18283.0  2011-06-30     524.68    131.170000            4
# 9370     18283.0  2011-09-30     278.09     92.696667            3
# 9371     18283.0  2011-12-31     974.21    162.368333            6
# ...

# %%
Month_group = {}
for i in range(len(df_3M['InvoiceDate'].unique())):
    Month_group[sorted(df_3M['InvoiceDate'].unique(), reverse=True)[i]] = f'M_{i+1}'
Month_group
# Out:
# {Timestamp('2011-12-31 00:00:00'): 'M_1',
#  Timestamp('2011-09-30 00:00:00'): 'M_2',
#  Timestamp('2011-06-30 00:00:00'): 'M_3',
#  Timestamp('2011-03-31 00:00:00'): 'M_4',
#  Timestamp('2010-12-31 00:00:00'): 'M_5'}

# %%
df_3M['Month_group'] = df_3M['InvoiceDate'].apply(lambda x: Month_group.get(x))
df_3M
# Out:
#       CustomerID InvoiceDate  Sales_sum     Sales_avg  Sales_count Month_group
# 0        12346.0  2011-03-31   77183.60  77183.600000            1         M_4
# 1        12347.0  2010-12-31     711.79    711.790000            1         M_5
# 2        12347.0  2011-03-31     475.39    475.390000            1         M_4
# 3        12347.0  2011-06-30    1018.77    509.385000            2         M_3
# 4        12347.0  2011-09-30     584.91    584.910000            1         M_2
# ...          ...         ...        ...           ...          ...         ...
# 9369     18283.0  2011-06-30     524.68    131.170000            4         M_3
# 9370     18283.0  2011-09-30     278.09     92.696667            3         M_2
# 9371     18283.0  2011-12-31     974.21    162.368333            6         M_1
# 9372     18287.0  2011-06-30     765.28    765.280000            1         M_3
# 9373     18287.0  2011-12-31    1072.00    536.000000            2         M_1
#
# [9374 rows x 6 columns]

# %% [markdown]
# ## Create pivot 3M_groupped table

# %%
df_3M_pivot = pd.pivot_table(data=df_3M,
                            index='CustomerID',
                            values=['Sales_sum', 'Sales_avg', 'Sales_count'],
                            columns='Month_group',
                            aggfunc='mean')
df_3M_pivot.columns = ['_'.join(col) for col in df_3M_pivot.columns]
df_3M_pivot = df_3M_pivot.reset_index()
df_3M_pivot = df_3M_pivot.fillna(0)
df_3M_pivot
# Out:
#       CustomerID  Sales_avg_M_1  Sales_avg_M_2  Sales_avg_M_3  Sales_avg_M_4  \
# 0        12346.0       0.000000       0.000000          0.000   77183.600000
# 1        12347.0     759.570000     584.910000        509.385     475.390000
# 2        12348.0       0.000000     310.000000        367.000     227.440000
# 3        12349.0    1757.550000       0.000000          0.000       0.000000
# 4        12350.0       0.000000       0.000000          0.000     334.400000
# ...          ...            ...            ...            ...            ...
# 4334     18280.0       0.000000       0.000000          0.000     180.600000
# 4335     18281.0       0.000000       0.000000         80.820       0.000000
# 4336     18282.0      77.840000     100.210000          0.000       0.000000
# 4337     18283.0     162.368333      92.696667        131.170     105.966667
# 4338     18287.0     536.000000       0.000000        765.280       0.000000
#
# ...

# %% [markdown]
# ## <span style='color:yellow'>Train Multi Linear Regression model and evaluate it

# %%
x = df_3M_pivot.drop(['CustomerID','Sales_avg_M_1', 'Sales_count_M_1', 'Sales_sum_M_1'], axis=1)
y = df_3M_pivot['Sales_sum_M_1'] #Sales_sum_M_1 is also the CLV_3M of M_1 group

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
linreg = LinearRegression().fit(x_train, y_train)

y_pred_test = linreg.predict(x_test)
y_pred_train = linreg.predict(x_train)

print(f'R^2 score (accuracy) on train set: {r2_score(y_train, y_pred_train)}')
print(f'R^2 score (accuracy) on test set: {r2_score(y_test, y_pred_test)}')
print()
print(f'MSE on test set: {mean_squared_error(y_test, y_pred_test)}')
print(f'MAE on test set: {mean_absolute_error(y_test, y_pred_test)}')
print()

plt.figure(figsize=(20,6))
sbn.set_theme(style='darkgrid')

plt.subplot(1,2,1)
plt.scatter(y_test, y_pred)
plt.plot([0,80000], [0,80000], '--', label='Reference line', color='green')
plt.xlabel('Y true')
plt.ylabel('Y preidct')
plt.legend()

plt.subplot(1,2,2)
sbn.kdeplot(y_test, color='orange', label='Y true')
sbn.kdeplot(y_pred_test, color='green', label='Y predict')
plt.legend()
plt.show()
# Out:
# R^2 score (accuracy) on train set: 0.2721728000707414
# R^2 score (accuracy) on test set: 0.8227280708664951
#
# MSE on test set: 1598262.7960917768
# MAE on test set: 512.571099721912

# %% [markdown]
# ## The model is "randomly" good on test set, but not on train set
