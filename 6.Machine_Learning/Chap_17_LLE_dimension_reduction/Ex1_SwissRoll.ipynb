# %% [markdown]
# # Chap 17 - Ex1: Apply LLE for Swiss Roll data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding

# %%
# Code for Generating a synthetic dataset (Swiss Roll)
n_samples = 1000
# Define the number of neighbors for LLE
n_neighbors = 10
X, _ = make_swiss_roll(n_samples=n_samples)

X
# Out:
# array([[ 5.94672102,  6.71426306, -1.24816077],
#        [ 6.05002771, 19.3687826 ,  2.96941018],
#        [ 5.38991951,  3.79334664, -2.33574363],
#        ...,
#        [ 9.86117213, 19.55832095,  8.9277031 ],
#        [-1.68113639, 18.96066398,  7.88681295],
#        [-4.10820249, 20.58459587, -9.76879464]])

# %%
lle = LocallyLinearEmbedding(n_neighbors=10, n_components=2) #n_components=10 means the transformed data will be 10-D
X_reduced = lle.fit_transform(X)

X_reduced
# Out:
# array([[ 0.03697598, -0.02551558],
#        [ 0.03048985,  0.06929319],
#        [ 0.03882826, -0.05015685],
#        ...,
#        [-0.05009579,  0.01703468],
#        [ 0.01773077,  0.03981991],
#        [-0.0116414 ,  0.0249821 ]])

# %%
# Code for Visualizing the original Versus reduced data
plt.figure(figsize=(12, 6))

plt.subplot(121)
plt.scatter(X[:, 0], X[:, 1], c=X[:, 2], cmap=plt.cm.Spectral)
plt.title("Original Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

plt.subplot(122)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=X[:, 2], cmap=plt.cm.Spectral)
plt.title("Reduced Data")
plt.xlabel("Component 1")
plt.ylabel("Component 2")

plt.tight_layout()
plt.show()
