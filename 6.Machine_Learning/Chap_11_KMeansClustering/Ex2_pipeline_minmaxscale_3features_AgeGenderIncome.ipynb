# %% [markdown]
# # Chap 11 - Ex2: classify customer into different groups based on data ageinc_g.csv (Age, Income, Gender)
# ## Use KMeansClustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

np.set_printoptions(suppress = True)

# %%
customer = pd.read_csv('Data/ageinc_g.csv', index_col = 0)
customer
# Out:
#      income  age  gender
# 0    101743   58  Female
# 1     49597   27  Female
# 2     36517   52    Male
# 3     33223   49    Male
# 4     72994   53  Female
# ..      ...  ...     ...
# 995   70615   29  Female
# 996   95102   41  Female
# 997   42203   35    Male
# 998   16975   31  Female
# 999  123857   44    Male
#
# [1000 rows x 3 columns]

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   income  1000 non-null   int64
#  1   age     1000 non-null   int64
#  2   gender  1000 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 31.2+ KB

# %%
customer.describe()
# Out:
#              income          age
# count    1000.00000  1000.000000
# mean    80116.81800    39.410000
# std     39262.33567    10.976811
# min         0.00000    18.000000
# 25%     46402.25000    30.000000
# 50%     78993.50000    39.000000
# 75%    114810.50000    49.000000
# max    179294.00000    63.000000

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(customer['income'], customer['age'], pd.get_dummies(customer['gender'], drop_first = True).astype(int))
ax.set_xlabel('Income')
ax.set_ylabel('Age')
ax.set_zlabel('Gender_Female')
plt.show()

# %% [markdown]
# ## <span style = 'color:yellow'> Check normal distribution and outliers of Income and Age

# %%
from scipy.stats import shapiro
print(f'Normality test of Income: {shapiro(customer['income'])}')
print(f'Normality test of Age: {shapiro(customer['age'])}')
print()

plt.subplot(1,2,1)
sbn.boxplot(data = customer, y = 'income')
plt.subplot(1,2,2)
sbn.boxplot(data = customer, y = 'age')
plt.show()

print('\nAge and Income are not normally distributed, but do not have outliers => can use MinMaxScaler')
# Out:
# Normality test of Income: ShapiroResult(statistic=0.95244171092576, pvalue=1.8452768011280746e-17)
# Normality test of Age: ShapiroResult(statistic=0.9490401537479766, pvalue=4.221272310083379e-18)
# Age and Income are not normally distributed, but do not have outliers => can use MinMaxScaler

# %% [markdown]
# ## <span style = 'color:yellow'> Find optimal K using Elbow Method and Silhoutte Score

# %%
#Use elbow method to find optimal K

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
import math

distortions = []
k_nums = range(2,10)

for k in k_nums:
    kmeans_pipe = Pipeline([
        ('OneHotEncoder', make_column_transformer((OneHotEncoder(drop='first', handle_unknown='ignore'), ['gender']), remainder='passthrough')),
        ('MinMaxScaler', MinMaxScaler()),
        ('KMeansModel', KMeans(n_clusters = k, random_state = 10))
    ])
    kmeans_pipe.fit(customer)
    customer_encode = kmeans_pipe.named_steps['OneHotEncoder'].transform(customer) #Transform original data with onehotencoder
    centroids = kmeans_pipe.named_steps['KMeansModel'].cluster_centers_
    centroids = kmeans_pipe.named_steps['MinMaxScaler'].inverse_transform(centroids) #Convert centroid coordinate back to original scale
    sum_var = sum(np.min(cdist(customer_encode, centroids, 'euclidean'), axis = 1)) / customer.shape[0]
    distortions.append(sum_var)
    labels = kmeans_pipe.named_steps['KMeansModel'].labels_
    print(f'Silhouette score for k = {k}: {silhouette_score(customer_transform, labels)}')

plt.plot(k_nums, distortions, 'bx-')
plt.xlabel('Number of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing optimal K')
plt.show()

print('\nChoose K = 4')
# Out:
# Silhouette score for k = 2: 0.0025201784614729025
# Silhouette score for k = 3: -0.0288010885978305
# Silhouette score for k = 4: -0.27135429017027096
# Silhouette score for k = 5: -0.12559277189662665
# Silhouette score for k = 6: -0.20817028703601428
# Silhouette score for k = 7: -0.15490257922308445
# Silhouette score for k = 8: -0.048443758734197415
# Silhouette score for k = 9: -0.07453251357238583
# Choose K = 4

# %% [markdown]
# ## <span style = 'color:yellow'> Build official KMeansClustering with K = 4

# %%
# Build officil KMeans model with K = 3

kmeans_pipe = Pipeline([
    ('OneHotEncoder', make_column_transformer((OneHotEncoder(drop='first', handle_unknown='ignore'), ['gender']), remainder='passthrough')),
    ('MinMaxScaler', MinMaxScaler()),
    ('KMeansModel', KMeans(n_clusters = 4, random_state = 10))
])

kmeans_pipe.fit(customer)

centroids = kmeans_pipe.named_steps['KMeansModel'].cluster_centers_
centroids = kmeans_pipe.named_steps['MinMaxScaler'].inverse_transform(centroids) #Convert centroid coordinate back to original scale
labels = kmeans_pipe.named_steps['KMeansModel'].labels_

print('Coordinate of all centroids:\n', centroids)

customer_group = kmeans_pipe.named_steps['OneHotEncoder'].transform(customer)
customer_group = pd.DataFrame(customer_group, columns = ['gender_Male', 'income', 'age'])
customer_group.insert(3, 'Group', labels)
print()
print(customer_group)
print()

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(centroids[:,1], centroids[:,2], centroids[:,0], marker = 's', s = 30, color = 'red')
ax.scatter(customer_group['income'], customer_group['age'], customer_group['gender_Male'], c = customer_group['Group'])
ax.set_xlabel('Income')
ax.set_ylabel('Age')
ax.set_zlabel('Gender_Male')
plt.show()
# Out:
# Coordinate of all centroids:
#  [[     0.          77061.10964912     50.3245614 ]
#  [     1.          82618.92172211     38.98238748]
#  [     0.          43276.84444444     30.42962963]
#  [     0.         114970.17460317     31.01587302]]
#
#      gender_Male    income   age  Group
# 0            0.0  101743.0  58.0      0
# 1            0.0   49597.0  27.0      2
# 2            1.0   36517.0  52.0      1
# 3            1.0   33223.0  49.0      1
# 4            0.0   72994.0  53.0      0
# ..           ...       ...   ...    ...
# 995          0.0   70615.0  29.0      2
# 996          0.0   95102.0  41.0      0
# 997          1.0   42203.0  35.0      1
# 998          0.0   16975.0  31.0      2
# 999          1.0  123857.0  44.0      1
#
# [1000 rows x 4 columns]

# %% [markdown]
# # <span style = 'color:yellow'> Report clustering results

# %%
# Method 1
for group in customer_group['Group'].unique():
    print(f'\n=============== Customer group {group} =========================\n')
    data = customer_group[customer_group['Group'] == group]
    
    for col_name in data.columns[:-1]:
        if col_name == 'gender_Male':
            #print(f'{col_name}: {data[col_name].sum()} / {data.shape[0]}')
            print(f'{data[col_name].value_counts().to_frame().reset_index()}')
            print()
        else:
            print(f'{col_name}: {np.min(data[col_name])} ~ {np.median(data[col_name])} ~ {np.max(data[col_name])}')
            print()
# Out:
# =============== Customer group 0 =========================
#
#    gender_Male  count
# 0          0.0    229
#
# income: 0.0 ~ 71381.0 ~ 175497.0
#
# age: 41.0 ~ 50.0 ~ 63.0
#
#
# =============== Customer group 2 =========================
#
#    gender_Male  count
# 0          0.0    135
#
# income: 0.0 ~ 45792.0 ~ 79360.0
#
# age: 18.0 ~ 30.0 ~ 45.0
#
#
# =============== Customer group 1 =========================
#
#    gender_Male  count
# 0          1.0    511
#
# income: 0.0 ~ 89117.0 ~ 175073.0
#
# age: 18.0 ~ 39.0 ~ 61.0
#
#
# =============== Customer group 3 =========================
#
#    gender_Male  count
# 0          0.0    125
#
# income: 80820.0 ~ 115334.0 ~ 179294.0
#
# age: 19.0 ~ 31.0 ~ 46.0

# %%
# Method 2
for group in customer_group['Group'].unique():
    print(f'\n=============== Customer group {group} =========================\n')
    print(customer_group[customer_group['Group'] == group].describe())
    print()
# Out:
# =============== Customer group 0 =========================
#
#        gender_Male         income         age  Group
# count        229.0     229.000000  229.000000  229.0
# mean           0.0   77365.358079   50.310044    0.0
# std            0.0   37799.580865    4.657096    0.0
# min            0.0       0.000000   41.000000    0.0
# 25%            0.0   44937.000000   47.000000    0.0
# 50%            0.0   71381.000000   50.000000    0.0
# 75%            0.0  110294.000000   54.000000    0.0
# max            0.0  175497.000000   63.000000    0.0
#
#
# =============== Customer group 2 =========================
#
#        gender_Male        income         age  Group
# count        135.0    135.000000  135.000000  135.0
# mean           0.0  43276.844444   30.429630    2.0
# std            0.0  17596.284531    5.769892    0.0
# min            0.0      0.000000   18.000000    2.0
# 25%            0.0  31136.000000   26.500000    2.0
# 50%            0.0  45792.000000   30.000000    2.0
# 75%            0.0  56576.000000   34.000000    2.0
# max            0.0  79360.000000   45.000000    2.0
#
#
# =============== Customer group 1 =========================
#
#        gender_Male         income         age  Group
# count        511.0     511.000000  511.000000  511.0
# mean           1.0   82618.921722   38.982387    1.0
# std            0.0   39526.888746   10.862315    0.0
# min            1.0       0.000000   18.000000    1.0
# 25%            1.0   47557.000000   29.000000    1.0
# 50%            1.0   89117.000000   39.000000    1.0
# 75%            1.0  116079.500000   48.000000    1.0
# max            1.0  175073.000000   61.000000    1.0
#
#
# =============== Customer group 3 =========================
#
#        gender_Male         income         age  Group
# count        125.0     125.000000  125.000000  125.0
# mean           0.0  114716.064000   30.888000    3.0
# std            0.0   17535.354326    5.329795    0.0
# min            0.0   80820.000000   19.000000    3.0
# 25%            0.0  103218.000000   28.000000    3.0
# 50%            0.0  115334.000000   31.000000    3.0
# 75%            0.0  126278.000000   34.000000    3.0
# max            0.0  179294.000000   46.000000    3.0

# %%
# Method 3:
for col_name in customer_group.columns[:-1]:
    if col_name == 'gender_Male':
        sbn.countplot(data = customer_group, x = 'Group', hue = col_name)
        plt.show()
    else:
        sbn.boxplot(data = customer_group, x = 'Group', y = col_name, hue = 'Group', palette = 'rainbow')
        plt.show()

# %%
customer_group['gender_Male'].value_counts()
# Out:
# gender_Male
# 1.0    511
# 0.0    489
# Name: count, dtype: int64
